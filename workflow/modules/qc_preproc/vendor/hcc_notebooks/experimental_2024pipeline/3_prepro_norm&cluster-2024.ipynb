# %%
import numpy as np
import scanpy as sc
import seaborn as sns
from scipy.stats import median_abs_deviation

sc.settings.verbosity = 0
sc.settings.set_figure_params(
    dpi=80,
    facecolor="white",
    frameon=False,
)

# %% [markdown]
# # Preprocessing - Quality control

# %% [markdown]
# Data cleaning is the first step in preprocessing scRNA-seq data. Its goal is to identify and remove cells that may not meet certain quality standarts, ensuring that the data used in downstream analysis is as reliable and accurate as possible.
#
# In single-cell experiments, not all cell produce high quality data. Some cells might be dead, damaged or compromised due to technical error during the experiment. If these low quality cells aren´t removed, they can introduce noise and skew the analysis, leading to incorrect conclusions. Data cleaning helps address these issues by filtering out problematic cells early in the process.
#
# First, we remove cells with high mitoncrondiral contents, as elevated levels of mithocondria RNA can indicate stressed or dying cells; this is managed by setting a maximum threshold for mitochondrial gene expression, in this analysis we set 20% as maximum value. Next, cells with low gene count are filtered out, since those expressing very few unique genes might be uninformative or reflect technical error; a minimum threshold is applied to exclude these low-quality cells. Lastly, outlier cells with unusually high or low gene expression, or other extreme characteristics, are identified and assessed. These outliers might be result of technical issues or represent rare cell types, and statistical methods are used to determine wheter they should be included or removed from the analysis.

# %%
adata = sc.read_h5ad('/datos/home/jupyter-mdiaz/scRNAseq_pipeline/adata_saved/doublet_remov.h5ad')

# %%
adata.var['mt'] = adata.var.index.str.startswith('MT-')

# %%
adata.var
# Out:
#                      gene_ids  n_cells     mt
# AL669831.3  ENSG00000230021.9      161  False
# MTND1P23    ENSG00000225972.1     2238  False
# MTND2P28    ENSG00000225630.1     1776  False
# MTCO1P12    ENSG00000237973.1     4217  False
# MIR6723     ENSG00000278791.1       33  False
# ...                       ...      ...    ...
# AL592183.1  ENSG00000273748.1       87  False
# AC240274.1  ENSG00000271254.6       15  False
# U1-6        ENSG00000275405.1       10  False
# AC233755.1  ENSG00000275063.1       12  False
# AC007325.4  ENSG00000278817.1       46  False
#
# [16096 rows x 3 columns]

# %%
sc.pp.calculate_qc_metrics(
    adata, qc_vars=["mt"], inplace=True, percent_top=[20], log1p=True
)
adata
# Out:
# AnnData object with n_obs × n_vars = 4522 × 16096
#     obs: 'n_genes', 'doublet', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt'
#     var: 'gene_ids', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: '_scvi_manager_uuid', '_scvi_uuid'

# %%
adata.var.sort_values('n_cells_by_counts')
# Out:
#                       gene_ids  n_cells     mt  n_cells_by_counts  \
# MIXL1       ENSG00000185155.11       10  False                  2
# AC106897.1   ENSG00000249679.1       16  False                  3
# AC007569.1   ENSG00000257221.3       11  False                  3
# HIST1H3C     ENSG00000278272.1       10  False                  3
# AC007386.2   ENSG00000232613.6       11  False                  3
# ...                        ...      ...    ...                ...
# MT-CO2       ENSG00000198712.1     5058   True               4521
# MT-ND4       ENSG00000198886.2     5058   True               4521
# MT-RNR2      ENSG00000210082.2     5058   True               4521
# MT-CO1       ENSG00000198804.2     5059   True               4522
# MT-CYB       ENSG00000198727.2     5059   True               4522
#
#             mean_counts  log1p_mean_counts  pct_dropout_by_counts  \
# MIXL1          0.000442           0.000442              99.955772
# AC106897.1     0.001106           0.001105              99.933658
# AC007569.1     0.000663           0.000663              99.933658
# HIST1H3C       0.000885           0.000884              99.933658
# AC007386.2     0.001106           0.001105              99.933658
# ...                 ...                ...                    ...
# MT-CO2       153.837234           5.042375               0.022114
# MT-ND4       128.781296           4.865851               0.022114
# MT-RNR2      108.731979           4.698041               0.022114
# MT-CO1       274.233734           5.617620               0.000000
# MT-CYB        88.570541           4.495027               0.000000
#
#             total_counts  log1p_total_counts
# MIXL1                2.0            1.098612
# AC106897.1           5.0            1.791759
# AC007569.1           3.0            1.386294
# HIST1H3C             4.0            1.609438
# AC007386.2           5.0            1.791759
# ...                  ...                 ...
# MT-CO2          695652.0           13.452606
# MT-ND4          582349.0           13.274827
# MT-RNR2         491686.0           13.105597
# MT-CO1         1240085.0           14.030691
# MT-CYB          400516.0           12.900512
#
# [16096 rows x 9 columns]

# %%
adata.obs
# Out:
#                   n_genes  doublet  n_genes_by_counts  \
# CellID
# CCGGGATAGCTAGTGG      821    False                818
# CGGACGTAGGGTGTGT      478    False                476
# TAGAGCTTCTGTGCAA      322    False                321
# ACTGATGAGACAAGCC     1584    False               1577
# TGGGCGTTCCATGAAC      243    False                243
# ...                   ...      ...                ...
# ACTATCTCAATAGCGG      396    False                396
# CTGCTGTTCCTAGAAC      254    False                254
# GCGCAACCACAACGTT      230    False                229
# CGGGTCACATCGGAAG      220    False                220
# TCACAAGTCCTGCTTG      306    False                304
#
#                   log1p_n_genes_by_counts  total_counts  log1p_total_counts  \
# CellID
# CCGGGATAGCTAGTGG                 6.708084        1939.0            7.570443
# CGGACGTAGGGTGTGT                 6.167516        1049.0            6.956545
# TAGAGCTTCTGTGCAA                 5.774552        4832.0            8.483223
# ACTGATGAGACAAGCC                 7.363914        5032.0            8.523771
# TGGGCGTTCCATGAAC                 5.497168        4133.0            8.327001
# ...                                   ...           ...                 ...
# ACTATCTCAATAGCGG                 5.983936         751.0            6.622736
# CTGCTGTTCCTAGAAC                 5.541264         646.0            6.472346
# GCGCAACCACAACGTT                 5.438079         559.0            6.327937
# CGGGTCACATCGGAAG                 5.398163         449.0            6.109248
# TCACAAGTCCTGCTTG                 5.720312         644.0            6.469250
#
#                   pct_counts_in_top_20_genes  total_counts_mt  \
# CellID
# CCGGGATAGCTAGTGG                   29.241877            364.0
# CGGACGTAGGGTGTGT                   42.040038            364.0
# TAGAGCTTCTGTGCAA                   91.928808           4247.0
# ACTGATGAGACAAGCC                   35.174881            878.0
# TGGGCGTTCCATGAAC                   93.443020           3691.0
# ...                                      ...              ...
# ACTATCTCAATAGCGG                   44.873502            285.0
# CTGCTGTTCCTAGAAC                   44.117647            196.0
# GCGCAACCACAACGTT                   45.796064            162.0
# CGGGTCACATCGGAAG                   54.565702            207.0
# TCACAAGTCCTGCTTG                   49.844720            160.0
#
#                   log1p_total_counts_mt  pct_counts_mt
# CellID
# CCGGGATAGCTAGTGG               5.899898      18.772564
# CGGACGTAGGGTGTGT               5.899898      34.699715
# TAGAGCTTCTGTGCAA               8.354203      87.893211
# ACTGATGAGACAAGCC               6.778785      17.448332
# TGGGCGTTCCATGAAC               8.213923      89.305588
# ...                                 ...            ...
# ACTATCTCAATAGCGG               5.655992      37.949402
# CTGCTGTTCCTAGAAC               5.283204      30.340559
# GCGCAACCACAACGTT               5.093750      28.980320
# CGGGTCACATCGGAAG               5.337538      46.102448
# TCACAAGTCCTGCTTG               5.081404      24.844721
#
# [4522 rows x 10 columns]

# %%
sc.pp.filter_genes(adata, min_cells=3)

# %%
p1 = sns.displot(adata.obs["total_counts"], bins=100, kde=False)
# sc.pl.violin(adata, 'total_counts')
p2 = sc.pl.violin(adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt'], 
             jitter=0.4, multi_panel=True))
p3 = sc.pl.scatter(adata, "total_counts", "n_genes_by_counts", color="pct_counts_mt")
# Out:
# /home/jupyter-mdiaz/.local/lib/python3.9/site-packages/scanpy/plotting/_anndata.py:906: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   ax = sns.violinplot(

# %%
adata.var.sort_values('n_cells_by_counts')
# Out:
#                      gene_ids  n_cells     mt  n_cells_by_counts  mean_counts  \
# AC106897.1  ENSG00000249679.1        3  False                  3     0.001106
# AC007569.1  ENSG00000257221.3        3  False                  3     0.000663
# HIST1H3C    ENSG00000278272.1        3  False                  3     0.000885
# AC007386.2  ENSG00000232613.6        3  False                  3     0.001106
# AC010654.1  ENSG00000277369.1        4  False                  4     0.000885
# ...                       ...      ...    ...                ...          ...
# MT-CO3      ENSG00000198938.2     4521   True               4521   189.078949
# MT-CO2      ENSG00000198712.1     4521   True               4521   153.837234
# MT-ND4      ENSG00000198886.2     4521   True               4521   128.781296
# MT-CYB      ENSG00000198727.2     4522   True               4522    88.570541
# MT-CO1      ENSG00000198804.2     4522   True               4522   274.233734
#
#             log1p_mean_counts  pct_dropout_by_counts  total_counts  \
# AC106897.1           0.001105              99.933658           5.0
# AC007569.1           0.000663              99.933658           3.0
# HIST1H3C             0.000884              99.933658           4.0
# AC007386.2           0.001105              99.933658           5.0
# AC010654.1           0.000884              99.911544           4.0
# ...                       ...                    ...           ...
# MT-CO3               5.247439               0.022114      855015.0
# MT-CO2               5.042375               0.022114      695652.0
# MT-ND4               4.865851               0.022114      582349.0
# MT-CYB               4.495027               0.000000      400516.0
# MT-CO1               5.617620               0.000000     1240085.0
#
#             log1p_total_counts
# AC106897.1            1.791759
# AC007569.1            1.386294
# HIST1H3C              1.609438
# AC007386.2            1.791759
# AC010654.1            1.609438
# ...                        ...
# MT-CO3               13.658875
# MT-CO2               13.452606
# MT-ND4               13.274827
# MT-CYB               12.900512
# MT-CO1               14.030691
#
# [16095 rows x 9 columns]

# %%
def is_outlier(adata, metric: str, nmads: int):
    M = adata.obs[metric]
    outlier = (M < np.median(M) - nmads * median_abs_deviation(M)) | (
        np.median(M) + nmads * median_abs_deviation(M) < M
    )
    return outlier

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4522 × 16096
#     obs: 'n_genes', 'doublet', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'outlier'
#     var: 'gene_ids', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: '_scvi_manager_uuid', '_scvi_uuid'

# %%
adata.obs["outlier"] = (
    is_outlier(adata, "log1p_total_counts", 5)
    | is_outlier(adata, "log1p_n_genes_by_counts", 5)
    | is_outlier(adata, "pct_counts_in_top_20_genes", 5)
)
adata.obs.outlier.value_counts()
# Out:
# outlier
# False    4522
# Name: count, dtype: int64

# %%
adata.obs["mt_outlier"] = is_outlier(adata, "pct_counts_mt", 3) | (
    adata.obs["pct_counts_mt"] > 25
)
adata.obs.mt_outlier.value_counts()
# Out:
# mt_outlier
# True     2302
# False    2220
# Name: count, dtype: int64

# %%
print(f"Total number of cells: {adata.n_obs}")
adata = adata[(~adata.obs.outlier) & (~adata.obs.mt_outlier)].copy()

print(f"Number of cells after filtering of low quality cells: {adata.n_obs}")
# Out:
# Total number of cells: 4522
# Number of cells after filtering of low quality cells: 2220

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 2220 × 16096
#     obs: 'n_genes', 'doublet', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_20_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'outlier', 'mt_outlier'
#     var: 'gene_ids', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: '_scvi_manager_uuid', '_scvi_uuid'

# %%
p1 = sc.pl.scatter(adata, "total_counts", "n_genes_by_counts", color="pct_counts_mt")

# %% [raw]
# import seaborn as sns
# import matplotlib.pyplot as plt
# import pandas as pd
#
# # Extrae las categorías necesarias y los valores
# categories = ['n_genes_by_counts', 'total_counts', 'pct_counts_mt']
#
# for category in categories:
#     # Crear un DataFrame para cada categoría
#     df = pd.DataFrame({
#         'categoría': [category] * len(adata.obs),
#         'valor': adata.obs[category]
#     })
#
#     # Crear el violin plot usando el DataFrame
#     plt.figure()
#     sns.violinplot(x="categoría", y="valor", data=df, inner=None)  # 'inner=None' para evitar duplicar los puntos
#     sns.stripplot(x="categoría", y="valor", data=df, color='black', alpha=0.3)  # Añadir los puntos
#
#     # Guarda la figura como una imagen
#     plt.savefig(f'violin_plot_{category}.png')
#
#     # Mostrar la figura
#     plt.show()

# %% [raw]
# import seaborn as sns
# import matplotlib.pyplot as plt
# import pandas as pd
#
# # Extrae las categorías necesarias y los valores
# categories = ['n_genes_by_counts', 'total_counts', 'pct_counts_mt']
# new_labels = {
#     'n_genes_by_counts': 'Genes totales',
#     'total_counts': 'Total de Transcritos',
#     'pct_counts_mt': 'DNA mitocondrial (%)'
# }
#
# for category in categories:
#     # Crear un DataFrame para cada categoría
#     df = pd.DataFrame({
#         'categoría': [new_labels[category]] * len(adata.obs),
#         'valor': adata.obs[category]
#     })
#
#     # Crear el violin plot usando el DataFrame
#     plt.figure()
#     sns.violinplot(x="categoría", y="valor", data=df, inner=None)  # 'inner=None' para evitar duplicar los puntos
#     sns.stripplot(x="categoría", y="valor", data=df, color='black', alpha=0.3)  # Añadir los puntos
#
#     # Guarda la figura como una imagen
#     plt.savefig(f'violin_plot_{category}.png')
#
#     # Mostrar la figura
#     plt.show()

# %% [markdown]
# # Normalization

# %% [markdown]
# Normalization is a critical step in the preprocessing of single-cell data. It adjusts for variability in the data that arises from differences in sequencing depth, cell size or other technical factors. This step ensures that differences observed between cells are due to biological variation rather than technical remnants.
#
# In Scanpy, the default method for normalization is **total-count normalization.** This approach involves scaling the raw counts for each cell by the total counts in that cell, followed by a logarithmic transformation to stabilize the data.

# %%
adata.X.sum(axis = 1)
# Out:
# matrix([[1939.],
#         [5032.],
#         [1637.],
#         ...,
#         [1711.],
#         [1712.],
#         [1057.]], dtype=float32)

# %% [markdown]
# **Scaling by Total Counts**
#
# This step adjusts each cell's counts to account for differences in sequencing depth or total RNA content. The common practice is to scale the counts by a constant factor, typically 10,000 (often called "counts per ten thousand," or CPTT). This step creates a common baseline across all cells.

# %%
sc.pp.normalize_total(adata, target_sum=1e4)
# Out:
# /home/jupyter-mdiaz/.local/lib/python3.9/site-packages/scanpy/preprocessing/_normalization.py:184: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
adata.X.sum(axis = 1)
# Out:
# matrix([[10000.   ],
#         [10000.001],
#         [10000.   ],
#         ...,
#         [10000.   ],
#         [ 9999.999],
#         [10000.   ]], dtype=float32)

# %% [markdown]
# **Logarithmic Transformation**
#
# After scaling, Scanpy applies a logarithmic transformation to the scaled counts. This transformation helps stabilize variance, making the data less sensitive to extreme values and facilitating downstream analysis.

# %%
sc.pp.log1p(adata)

# %%
adata.X.sum(axis = 1)
# Out:
# matrix([[1758.7179],
#         [2254.3665],
#         [1675.0664],
#         ...,
#         [1594.5846],
#         [1628.174 ],
#         [1562.9828]], dtype=float32)

# %%
adata.raw = adata

# %% [markdown]
# # Clustering

# %% [markdown]
# In single-cell analysis, the goal is often to explore cellular diversity and identify unique cell types or states. Clustering allows us to categorize cells based on their gene expression profiles, providing insights into the composition of a sample. This step is critical for many downstream analyses, including identifying diferentially expressed genes and visualizing complex datasets.
#
# Single-cell data typically has thousands of genes, making it high-dimensional. Before clustering, dimensionality reduction techniques PCA (Principal Component Analysis) and UMAP (Uniform Manifold Approximation and Projection) are used to reduce the data to a lower-dimensional space. This step helps focus on the most informative features while reducing noise.
#
# There are several clustering methods, the most common are:
#
# - K-means clustering
# - Hierarchical Clustering
# - Graph-based Clustering
#
# Here we use a Graph-based Clustering. This is a common approach in scRNA-seq analysis that organizes cells into groups based on their connectivity in a graph structure. For this purpose, we employed **Leiden algorithm** which is a popular graph-based clustering method known for its efficiency, accuracy, and robustness. It is widely used in single-cell analysis due to its ability to find well-defined clusters in complex datasets.

# %% [markdown]
# ### Leiden
#
# Leiden starts by constructing a "neighbor graph," where each node represents a cell, and edges represent connections between cells based on their similarity (often measured using k-nearest neighbors or other distance metrics). The algorithm then applies a process called "community detection" to identify clusters of closely related cells within the graph.
#
# Leiden is an improvement over the earlier Louvain algorithm, offering better cluster quality and avoiding some common issues, such as instability or disconnected clusters. It does this through several key steps:
#
# - Node Partitioning: Leiden assigns cells (nodes) to initial clusters, creating a partition of the graph.
# - Node Refinement: The algorithm refines the partition by evaluating the modularity (a measure of the strength of clusters) and moving nodes to improve modularity.
# - Cluster Optimization: Leiden continues refining clusters until no further improvements can be made.
#
# The final output is a set of clusters that represent distinct groups of cells, which can be used for downstream analyses like visualization, differential expression, or cell-type annotation.

# %%
sc.pp.highly_variable_genes(adata, n_top_genes = 2000)

# %%
adata.var
# Out:
#                      gene_ids  n_cells     mt  n_cells_by_counts  mean_counts  \
# AL669831.3  ENSG00000230021.9      139  False                139     0.031181
# MTND1P23    ENSG00000225972.1     1900  False               1900     1.143299
# MTND2P28    ENSG00000225630.1     1524  False               1524     0.642415
# MTCO1P12    ENSG00000237973.1     3691  False               3691     8.787483
# MIR6723     ENSG00000278791.1       26  False                 26     0.005971
# ...                       ...      ...    ...                ...          ...
# AL592183.1  ENSG00000273748.1       61  False                 61     0.014374
# AC240274.1  ENSG00000271254.6       12  False                 12     0.002654
# U1-6        ENSG00000275405.1        6  False                  6     0.001327
# AC233755.1  ENSG00000275063.1        7  False                  7     0.007077
# AC007325.4  ENSG00000278817.1       30  False                 30     0.006634
#
#             pct_dropout_by_counts  total_counts  highly_variable     means  \
# AL669831.3              96.926139         141.0            False  0.057497
# MTND1P23                57.983193        5170.0            False  0.786593
# MTND2P28                66.298098        2905.0            False  0.611349
# MTCO1P12                18.376824       39737.0            False  2.238604
# MIR6723                 99.425033          27.0            False  0.012843
# ...                           ...           ...              ...       ...
# AL592183.1              98.651039          65.0            False  0.116762
# AC240274.1              99.734631          12.0            False  0.023685
# U1-6                    99.867315           6.0            False  0.004686
# AC233755.1              99.845201          32.0            False  0.017016
# AC007325.4              99.336577          30.0            False  0.031171
#
#             dispersions  dispersions_norm
# AL669831.3     1.692383         -0.553464
# MTND1P23       1.928615         -0.402576
# MTND2P28       1.912279         -0.339875
# MTCO1P12       2.002842         -0.857025
# MIR6723        1.805048         -0.174375
# ...                 ...               ...
# AL592183.1     1.863479          0.022230
# AC240274.1     1.619186         -0.799752
# U1-6           1.072328         -2.639791
# AC233755.1     2.045175          0.633591
# AC007325.4     1.755085         -0.342487
#
# [16095 rows x 11 columns]

# %%
sc.pl.highly_variable_genes(adata)

# %%
adata = adata[:, adata.var.highly_variable]

# %%
sc.pp.regress_out(adata, ['total_counts', 'pct_counts_mt'])
# Out:
# /home/jupyter-mdiaz/.local/lib/python3.9/site-packages/scanpy/preprocessing/_simple.py:640: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)

# %%
sc.pp.scale(adata, max_value=10)

# %%
sc.tl.pca(adata, svd_solver='arpack')

# %%
sc.pl.pca_variance_ratio(adata, log=True, n_pcs = 50)

# %%
sc.pp.neighbors(adata, n_pcs = 30)

# %%
sc.tl.umap(adata)
sc.pl.umap(adata)
# Out:
# /home/jupyter-mdiaz/.local/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:401: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   cax = scatter(

# %%
sc.tl.leiden(adata, resolution = 1)

# %%
adata.obs
# Out:
#                   n_genes  doublet  n_genes_by_counts  total_counts  \
# CellID
# CCGGGATAGCTAGTGG      821    False                818        1939.0
# ACTGATGAGACAAGCC     1584    False               1577        5032.0
# GACTGCGGTCAGATAA      741    False                737        1637.0
# GGCGACTGTAGGAGTC     1338    False               1334        3086.0
# CCATTCGTCAACCATG     1246    False               1242        3220.0
# ...                   ...      ...                ...           ...
# TTCGAAGTCCGTCATC      879    False                876        1724.0
# GGGATGAGTTAAAGAC      685    False                681        1322.0
# CTACCCATCTGTTGAG      704    False                703        1711.0
# TAGACCAAGAGTGACC      713    False                712        1712.0
# ACGGCCAAGAAAGTGG      600    False                600        1057.0
#
#                   total_counts_mt  pct_counts_mt leiden
# CellID
# CCGGGATAGCTAGTGG            364.0      18.772564      1
# ACTGATGAGACAAGCC            878.0      17.448332     11
# GACTGCGGTCAGATAA            276.0      16.860109      0
# GGCGACTGTAGGAGTC            323.0      10.466623      6
# CCATTCGTCAACCATG            404.0      12.546584      3
# ...                           ...            ...    ...
# TTCGAAGTCCGTCATC            233.0      13.515080      2
# GGGATGAGTTAAAGAC            197.0      14.901665      2
# CTACCCATCTGTTGAG            246.0      14.377557      5
# TAGACCAAGAGTGACC            217.0      12.675233      4
# ACGGCCAAGAAAGTGG            141.0      13.339641      1
#
# [1724 rows x 7 columns]

# %%
sc.pl.umap(adata, color=['leiden'])
# Out:
# /home/jupyter-mdiaz/.local/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:401: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
adata.write_h5ad('/datos/home/jupyter-mdiaz/scRNAseq_pipeline/adata_saved/P1_QC.h5ad')
